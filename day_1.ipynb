# %%
#unit convertor 


rupees = float(input("Enter Rupees: "))
rate = float(input("Enter current USD rate (1 INR = ? USD): "))

dollar = rupees * rate

print(f"{rupees} INR = {dollar:.2f} USD")
# Out:
# Enter Rupees:  500
# Enter current USD rate (1 INR = ? USD):  .07
# 500.0 INR = 35.00 USD
