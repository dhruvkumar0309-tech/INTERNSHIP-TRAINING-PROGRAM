# %%
#Positive/Negative Checker

num = float(input("Enter a number: "))

if num > 0:
    print("Positive Number")
elif num < 0:
    print("Negative Number")
else:
    print("Zero")
# Out:
# Enter a number:  50
# Positive Number
